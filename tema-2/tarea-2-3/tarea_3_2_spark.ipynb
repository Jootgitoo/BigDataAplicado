# %% [markdown]
# # 1. Instalamos PySpark y findspark

# %%
# !pip install -q pyspark findspark

# %% [markdown]
# # 2. Configurar Java

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"

# %% [markdown]
# # 3. Inicializar findspark

# %%
import findspark
findspark.init()

# %% [markdown]
# # 4. Creamos SparkSession

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Pi") \
    .master("local[*]") \
    .getOrCreate()

sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local[*] appName=Pi>

# %% [markdown]
# # 5. Utilizamos el método Montecarlo

# %%
import random

num_samples = 1000000

def inside(p):
    x, y = random.random(), random.random()
    return x*x + y*y < 1

# %% [markdown]
# # 6. Paralelización

# %%
count = sc.parallelize(range(num_samples)).filter(inside).count()
pi = 4 * count / num_samples
print(pi)
# Out:
# 3.138936

# %% [markdown]
# # 7. Paramos el SparkContext

# %%
spark.stop()
