# %% [markdown]
# # Instalamos Hadoop en Colab

# %%
#Actualizamos los repositorios
# !apt-get update
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
#Instalamos la version 11 de Java
# !apt-get install openjdk-11-jdk-headless -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   openjdk-11-jre-headless
# Suggested packages:
#   openjdk-11-demo openjdk-11-source libnss-mdns fonts-dejavu-extra
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   openjdk-11-jdk-headless openjdk-11-jre-headless
# 0 upgraded, 2 newly installed, 0 to remove and 118 not upgraded.
# Need to get 116 MB of archives.
# After this operation, 258 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.30+7-1ubuntu1~22.04 [42.6 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jdk-headless amd64 11.0.30+7-1ubuntu1~22.04 [73.7 MB]
# Fetched 116 MB in 7s (16.0 MB/s)
# ...

# %%
#Configuramos el JAVA_HOME
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"

# %%
# Instalamos una verison reciente de hadoop
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.4.2/hadoop-3.4.2.tar.gz
# Out:
# --2026-03-07 12:27:12--  https://downloads.apache.org/hadoop/common/hadoop-3.4.2/hadoop-3.4.2.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 135.181.214.104, 88.99.208.237, 2a01:4f9:3a:2c57::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|135.181.214.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1065831750 (1016M) [application/x-gzip]
# Saving to: ‘hadoop-3.4.2.tar.gz’
#
# hadoop-3.4.2.tar.gz 100%[===================>]   1016M  14.1MB/s    in 67s
#
# 2026-03-07 12:28:20 (15.2 MB/s) - ‘hadoop-3.4.2.tar.gz’ saved [1065831750/1065831750]

# %% [markdown]
# # Descomprimimos hadoop

# %%
# !tar -xzf hadoop-3.4.2.tar.gz

# %%
# Movemos hadoop a /usr/local
# !mv hadoop-3.4.2 /usr/local/hadoop-3.4.2

# %% [markdown]
# # Configuramos las variables de entorno

# %%
import os

os.environ["HADOOP_HOME"] = "/usr/local/hadoop-3.4.2"
os.environ["PATH"] += ":/usr/local/hadoop-3.4.2/bin"
os.environ["PATH"] += ":/usr/local/hadoop-3.4.2/sbin"

# %% [markdown]
# # Descargamos el dataset de noticias

# %%
# !wget http://qwone.com/~jason/20Newsgroups/20news-18828.tar.gz
# Out:
# --2026-03-07 12:34:55--  http://qwone.com/~jason/20Newsgroups/20news-18828.tar.gz
# Resolving qwone.com (qwone.com)... 173.48.205.131
# Connecting to qwone.com (qwone.com)|173.48.205.131|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14666916 (14M) [application/x-gzip]
# Saving to: ‘20news-18828.tar.gz’
#
# 20news-18828.tar.gz 100%[===================>]  13.99M  1.88MB/s    in 8.5s
#
# 2026-03-07 12:35:04 (1.64 MB/s) - ‘20news-18828.tar.gz’ saved [14666916/14666916]

# %%
#Descomprimimos
# !tar -xzf 20news-18828.tar.gz

# %% [markdown]
# # Ejecutamos MapReduce

# %%
# !/usr/local/hadoop-3.4.2/bin/hadoop jar /usr/local/hadoop-3.4.2/share/hadoop/tools/lib/hadoop-streaming-3.4.2.jar \
-input /content/20news-18828/alt.atheism/49960 \
-output /content/output \
-file /content/mapper.py \
-file /content/reducer.py \
-mapper "python mapper.py" \
-reducer "python reducer.py"
# Out:
# 2026-03-07 12:35:28,508 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapper.py, /content/reducer.py] [] /tmp/streamjob1348834976044430115.jar tmpDir=null
# 2026-03-07 12:35:29,962 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-03-07 12:35:30,285 INFO mapred.FileInputFormat: Total input files to process : 1
# 2026-03-07 12:35:30,322 INFO mapreduce.JobSubmitter: number of splits:1
# 2026-03-07 12:35:30,963 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local169913969_0001
# 2026-03-07 12:35:30,965 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2026-03-07 12:35:31,644 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper.py as file:/tmp/hadoop-root/mapred/local/job_local169913969_0001_87a585bd-df7b-4e67-ad29-cc2c2e628214/mapper.py
# ...

# %%
#Mostramos la solucion por pantalla
# !cat /content/output/part-00000
# Out:
# 034529887x	1
# 0511211216	1
# 071	5
# 080182494x	1
# 0801834074	1
# 0877226423	1
# 0877227675	1
# 0908	1
# 0910309264	1
# 1	1
# 10	1
# 11	1
# 1266	1
# 1271	1
# 14	1
# 140195	1
# 14215	1
# 14226	1
# 142282197	1
# 17701900	1
# 1881	1
# 1977	1
# 1981	1
# 1986	1
# 1988	1
# 1989	1
# 1990	1
# 1992	1
# 20th	1
# 226	1
# 24hour	1
# 2568900	1
# 272	1
# 273	1
# 2nd	1
# 3005	1
# 316	1
# 372	1
# 3d	1
# 3nl	1
# 4	1
# 41	2
# 430	2
# 4581244	1
# 4679525	1
# 490	1
# 495	2
# 4rh	1
# 4rl	1
# 512	2
# 53701	1
# 541	1
# 59	1
# 608	1
# 664	1
# 700	1
# 702	1
# 7119	1
# 716	1
# 7215	1
# 7251	1
# 750	1
# 7723	1
# 787140195	1
# 787522973	1
# 831	1
# 8372475	1
# 88	1
# 880	2
# 8964079	1
# 8ew	1
# 91605	1
# aah	1
# aap	2
# abortions	1
# absurdities	1
# accompanied	1
# accounts	1
# address	1
# addresses	2
# adulteries	1
# aesthetics	1
# african	3
# africanamericans	1
# agnostic	1
# al	1
# alien	1
# allen	2
# also	3
# altatheism	1
# altatheismarchivename	1
# altatheismmoderated	1
# alternate	1
# alternative	1
# ...
